# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Jaime Cortes**
#
#
# Software Expert - SOA Integration Engineer

# %% [markdown]
# *I am interested in data science because, i would to contribute towards affordable and quality healthcare in the future*

# %% [markdown]
# The next line must print Hello Friend! in spanish.

# %%
print("Hola Amigo!");
# Out:
# Hola Amigo!

# %% [markdown]
# ### horizontal rule:
# text1
# ___
# text2
# ___
# text3
# ___
#
# <br>
#
# ### bulleted list
# * Text1
# * Text2
# * Text3
#
#
# <br>
#
# ### numbered list
# 1. Text1
# 1. Text2
# 1. Text3
#
# <br>
#
# ### tables
#
# | Table1   |      TXT     |
# |----------|:-------------:|
# | This is  |  a cool table |
#
# ___
#
#
# | Table2   |      TXT     |
# |----------|:-------------:|
# | This is  |  a cool table |
#
#
# ___
#
#
# | Table3   |      TXT     |
# |----------|:-------------:|
# | This is not |  a cool table |
#
#
# <br>
#
# ### hyperlinks
#
# [Colombian news1](https://www.eltiempo.com)
#
# [IBM](https://www.ibm.com)
#
#
# [Colombian news2](https://www.elespectador.com)
#
# <br>
#
# ### Images
#
# ![random Img 1](http://placeimg.com/234/120/nature/grayscale)
# ![random Img 2](http://placeimg.com/234/120/tech/grayscale)
# ![random Img 3](http://placeimg.com/234/120/animals/grayscale)
#
#
# ### Code/syntax highlighting
#
# ```javascript
# var s = "JavaScript syntax highlighting";
# alert(s);
# ```
#
# ```python
# s = "Python syntax highlighting"
# print s
# ```
#
# <br>
#
#
# ### Blockquotes
# > Blockquotes are very handy in email to emulate reply text.
# > This line is part of the same quote.
#
# Quote break.
#
# > This is it.
#
#
# <br>
#
# ### Strikethrough
#
# This is true; ~~This is not true anymore~~
